# %%
# !pip install tmdbv3api

# %%
# Importing relevant functions
from tmdbv3api import TMDb, Movie
import pandas as pd

# Loading dataset 
df = pd.read_csv("movies.csv")

# %%
import requests
import time
from typing import Dict, Optional

# API Initialization 
API_KEY = "880680398c355c1d81499545135a1dde"
BASE_URL = "https://api.themoviedb.org/3"

# Defines a function that finds a movie title and release year (optional) to find a match
def search_movie(title: str, year: Optional[int] = None) -> Optional[Dict]:
    """Search for a movie by title and optionally year"""
    search_url = f"{BASE_URL}/search/movie" # buliding the API URL to search for a movie 
    # Creating a dictionary of parameters to send with request
    params = {
        'api_key': API_KEY,
        'query': title
    }
    # If year was provided, add it to search parameters for more precise matching
    if year:
        params['year'] = year

    # Send GET request to TMDB API with parameters
    response = requests.get(search_url, params=params)
    
    # Checking if API request was successful
    if response.status_code == 200:
        data = response.json() # Converts JSON response to Python dictionary 
        if data['results']:
            return data['results'][0]  # Return first match (the most relevant) 
    # If API failed or no results found, return None
    return None

# %%
# Function finds information from movie ID found in the search 
def get_movie_details(movie_id: int) -> Optional[Dict]:
    """Get detailed movie information including budget, revenue, and runtime"""
    details_url = f"{BASE_URL}/movie/{movie_id}" # Building URL for specific movie information 
    params = {
        'api_key': API_KEY
    }
    # Sending request
    response = requests.get(details_url, params=params)
    # Checking if successful 
    if response.status_code == 200:
        return response.json() # Converts JSON response to Python dictionary
    return None # If API failed or no results found, return None

def extract_movie_data(title: str, year: Optional[int] = None) -> Dict:
    """Complete function to get budget, revenue, and runtime for a movie"""
    # First, search for the movie using title and year
    movie_search = search_movie(title, year)

    # If not found, return None
    if not movie_search:
        return {
            'title': title, # original title 
            'tmdb_id': None, 
            'budget': None,
            'revenue': None,
            'runtime': None,
            'genres': None, 
            'keywords': None,
            'tagline': None,
            'overview': None,
            'status': 'not_found' # no information found
        }

    # Get detailed information using movie ID from search result 
    movie_details = get_movie_details(movie_search['id'])

    # If details failed to be retreived, partial return success 
    if not movie_details:
        return {
            'title': title, # original title 
            'tmdb_id': movie_search['id'], # ID was found 
            'budget': None,
            'revenue': None,
            'runtime': None,
            'genres': None, 
            'keywords': None,
            'tagline': None,
            'overview': None,
            'status': 'details_failed' # no details found
        }
    # If found all requested details, return complete result 
    return {
        'title': title,
        'tmdb_id': movie_search['id'],
        'budget': movie_details.get('budget', 0),
        'revenue': movie_details.get('revenue', 0),
        'runtime': movie_details.get('runtime'),
        'genres': movie_details.get('genres'), 
        'keywords': movie_details.get('keywords'),
        'tagline': movie_details.get('tagline'),
        'overview': movie_details.get('overview'),
        'status': 'success'
    }

# Iterates through each movie, calls the extraction function, adds to original dataset 
def enrich_movie_dataset(df: pd.DataFrame, batch_size: int = 50) -> pd.DataFrame:
    """
    Enrich the movie dataset with TMDB data
    Processes in batches with rate limiting to respect API limits
    """
    enriched_data = [] # Empty list to store all new movie records

    # Loop through each row
    for index, row in df.iterrows():
        # Prints progress message showing current movie being processed
        print(f"Processing {index + 1}/{len(df)}: {row['Title']} ({row['Year']})")

        # Extract movie data from TMDB by calling the extraction function 
        movie_data = extract_movie_data(row['Title'], row['Year'])

        # Combine original row data with TMDB data
        enriched_row = row.to_dict() # converts to dictionary 
        enriched_row.update(movie_data) # merges the movie_data dictionary into enriched_row
        enriched_data.append(enriched_row) # adds enriched_row to results

        # Rate limiting - TMDB allows 40 requests per 10 seconds
        if (index + 1) % batch_size == 0: # checks if a full batch has been processed 
            print(f"Processed {index + 1} movies. Pausing for rate limiting...") # pauses longer if the batch limit has been reached
            time.sleep(10) # Waiting 10 seconds
        else:
            time.sleep(0.25)  # Small delay between requests when batch limit hasn't been met

    # Convert back to a dataframe 
    return pd.DataFrame(enriched_data)

# %%
# Processing all 9,515 movies in the original Kaggle Dataset
print("=== TMDB API Movie Data Enrichment for All Movies ===\n")

# Load Kaggle dataset 
df = pd.read_csv('movies.csv')

# Run the enrichment on the entire dataset
# Calls above function
enriched_df = enrich_movie_dataset(df)

# Display results
print("\n=== Final Results ===")
print(f"Movies processed: {len(enriched_df)}") # shows the total number of movies that we iterated over
print(f"Successfully matched: {len(enriched_df[enriched_df['status'] == 'success'])}") # movies with successfully found information 
print(f"Not found: {len(enriched_df[enriched_df['status'] == 'not_found'])}") # movies that couldn't be found in TMDb database
print(f"Details failed: {len(enriched_df[enriched_df['status'] == 'details_failed'])}") # movies that details couldn't be retreived 

# Save the final enriched dataset
enriched_df.to_csv('movies_with_tmdb_data_complete.csv', index=False)
print(f"\nComplete enriched dataset saved to 'movies_with_tmdb_data_complete.csv'")

# Show sample of enriched data
print("\nSample of enriched data:")
columns_to_show = ['Title', 'Year', 'budget', 'revenue', 'runtime', 'genres', 'keywords', 'tagline', 'overview', 'status']
print(enriched_df[columns_to_show].head(10).to_string(index=False))

# Prints completion message 
print("\n" + "="*60) # prints a blank line and then 60 equals signs
print("PROCESSING COMPLETE!") # message 
print("="*60) # 60 equals signs
# Out:
# === TMDB API Movie Data Enrichment for All Movies ===
#
# Loading dataset...
# Dataset loaded: 9515 movies total
#
# Processing ALL movies:
# This will take approximately 1-2 hours due to rate limiting...
# Progress will be saved every 500 movies in case of interruption.
#
# Processing 1/9515: The Irishman (2019)
# Processing 2/9515: Dangal (2016)
# Processing 3/9515: David Attenborough: A Life on Our Planet (2020)
# Processing 4/9515: Lagaan: Once Upon a Time in India (2001)
# Processing 5/9515: Roma (2018)
# Processing 6/9515: To All the Boys I've Loved Before (2018)
# Processing 7/9515: The Social Dilemma (2020)
# Processing 8/9515: Okja (2017)
# Processing 9/9515: The Ballad of Buster Scruggs (2018)
# Processing 10/9515: The Trial of the Chicago 7 (2020)
# Processing 11/9515: Article 15 (2019)
# Processing 12/9515: Jim & Andy: The Great Beyond- Featuring a Very Special, Contractually Obligated Mention of Tony Clifton (2017)
# Processing 13/9515: Dolemite Is My Name (2019)
# Processing 14/9515: Mudbound (2017)
# Processing 15/9515: Swades (2004)
# Processing 16/9515: Fyre (2019)
# Processing 17/9515: Miss Americana (2020)
# Processing 18/9515: Virunga (2014)
# Processing 19/9515: Black Friday (2004)
# Processing 20/9515: Talvar (2015)
# Processing 21/9515: The King (2019)
# Processing 22/9515: John Mulaney: Kid Gorgeous at Radio City (2018)
# Processing 23/9515: I Am Mother (2019)
# Processing 24/9515: Tell Me Who I Am (2019)
# Processing 25/9515: The Departed (2006)
# Processing 26/9515: Winter on Fire: Ukraine's Fight for Freedom (2015)
# Processing 27/9515: Terminator 2: Judgment Day (1991)
# Processing 28/9515: I Lost My Body (2019)
# Processing 29/9515: Django Unchained (2012)
# Processing 30/9515: The Half of It (2020)
# Processing 31/9515: The Boy Who Harnessed the Wind (2019)
# Processing 32/9515: The Devil All the Time (2020)
# Processing 33/9515: The Fundamentals of Caring (2016)
# Processing 34/9515: Pieces of a Woman (2020)
# Processing 35/9515: Gerald's Game (2017)
# Processing 36/9515: On Body and Soul (2017)
# Processing 37/9515: Shutter Island (2010)
# Processing 38/9515: Always Be My Maybe (2019)
# Processing 39/9515: The Intouchables (2011)
# Processing 40/9515: Bill Burr: Paper Tiger (2019)
# Processing 41/9515: Special 26 (2013)
# Processing 42/9515: Kiss the Ground (2020)
# Processing 43/9515: Crip Camp: A Disability Revolution (2020)
# Processing 44/9515: Extraction (2020)
# Processing 45/9515: No Direction Home: Bob Dylan (2005)
# Processing 46/9515: Kabhi Khushi Kabhie Gham (2001)
# Processing 47/9515: His House (2020)
# Processing 48/9515: Super Deluxe (2019)
# Processing 49/9515: The Guernsey Literary & Potato Peel Pie Society (2018)
# Processing 50/9515: A Secret Love (2020)
# Processed 50 movies. Pausing for rate limiting...
# Processing 51/9515: The Night Comes for Us (2018)
# Processing 52/9515: The Big Lebowski (1998)
# Processing 53/9515: Pad Man (2018)
# Processing 54/9515: American Factory (2019)
# Processing 55/9515: Bird Box (2018)
# Processing 56/9515: The Pianist (2002)
# Processing 57/9515: 3 Idiots (2009)
# Processing 58/9515: The Distinguished Citizen (2016)
# Processing 59/9515: A Shaun the Sheep Movie: Farmageddon (2019)
# Processing 60/9515: A Clockwork Orange (1971)
# Processing 61/9515: What Happened to Monday (2017)
# Processing 62/9515: Anthony Jeselnik: Thoughts and Prayers (2015)
# Processing 63/9515: The White Helmets (2016)
# Processing 64/9515: Invader ZIM: Enter the Florpus (2019)
# Processing 65/9515: Happy as Lazzaro (2018)
# Processing 66/9515: Chasing Coral (2017)
# Processing 67/9515: Kal Ho Naa Ho (2003)
# Processing 68/9515: Pan's Labyrinth (2006)
# Processing 69/9515: Team Foxcatcher (2016)
# Processing 70/9515: The Meyerowitz Stories (New and Selected) (2017)
# Processing 71/9515: Casino Royale (2006)
# Processing 72/9515: The Hateful Eight (2015)
# Processing 73/9515: Rush (2013)
# Processing 74/9515: Zombieland (2009)
# Processing 75/9515: Eurovision Song Contest: The Story of Fire Saga (2020)
# Processing 76/9515: Kapoor & Sons (2016)
# Processing 77/9515: The Perfection (2018)
# Processing 78/9515: Dave Chappelle: Sticks & Stones (2019)
# Processing 79/9515: There Will Be Blood (2007)
# Processing 80/9515: Million Dollar Baby (2004)
# Processing 81/9515: The Social Network (2010)
# Processing 82/9515: The Christmas Chronicles (2018)
# Processing 83/9515: Monty Python and the Holy Grail (1975)
# Processing 84/9515: The Pixar Story (2007)
# Processing 85/9515: Ma Rainey's Black Bottom (2020)
# Processing 86/9515: Calibre (2018)
# Processing 87/9515: Silver Linings Playbook (2012)
# Processing 88/9515: Over the Moon (2020)
# Processing 89/9515: What Happened, Miss Simone? (2015)
# Processing 90/9515: Nightcrawler (2014)
# Processing 91/9515: 1922 (2017)
# Processing 92/9515: Paddleton (2019)
# Processing 93/9515: Cargo (2017)
# Processing 94/9515: Rain Man (1988)
# Processing 95/9515: Cuba and the Cameraman (2017)
# Processing 96/9515: The Ritual (2017)
# Processing 97/9515: The Hater (2020)
# Processing 98/9515: The Edge of Democracy (2019)
# Processing 99/9515: 22-Jul (2018)
# Processing 100/9515: Adam Sandler: 100% Fresh (2018)
# Processed 100 movies. Pausing for rate limiting...
# Processing 101/9515: Guru (2007)
# Processing 102/9515: A Twelve-Year Night (2018)
# Processing 103/9515: Dumplin' (2018)
# Processing 104/9515: The Conjuring (2013)
# Processing 105/9515: Marriage Story (2019)
# Processing 106/9515: My Octopus Teacher (2020)
# Processing 107/9515: About Time (2013)
# Processing 108/9515: Hey Arnold! The Jungle Movie (2017)
# Processing 109/9515: Kung Fu Panda (2008)
# Processing 110/9515: Superbad (2007)
# Processing 111/9515: The Invisible Guest (2016)
# Processing 112/9515: Chinatown (1974)
# Processing 113/9515: Mystic River (2003)
# Processing 114/9515: The Theory of Everything (2014)
# Processing 115/9515: Springsteen On Broadway (2018)
# Processing 116/9515: The Life Ahead (2020)
# Processing 117/9515: The Terminal (2004)
# Processing 118/9515: Scott Pilgrim vs. the World (2010)
# Processing 119/9515: Being Elmo: A Puppeteer's Journey (2011)
# Processing 120/9515: Life of Brian (1979)
# Processing 121/9515: The Resistance Banker (2018)
# Processing 122/9515: How to Train Your Dragon 2 (2014)
# Processing 123/9515: The Endless Trench (2019)
# Processing 124/9515: Even the Rain (2010)
# Processing 125/9515: Love Actually (2003)
# Processing 126/9515: Dear Ex (2018)
# Processing 127/9515: Braven (2018)
# Processing 128/9515: Period. End of Sentence. (2018)
# Processing 129/9515: Captain Fantastic (2016)
# Processing 130/9515: Veronica (2017)
# Processing 131/9515: The Siege of Jadotville (2016)
# Processing 132/9515: Into the Inferno (2016)
# Processing 133/9515: Ricky Gervais: Humanity (2018)
# Processing 134/9515: A Whisker Away (2020)
# Processing 135/9515: Lady Bird (2017)
# Processing 136/9515: Road to Perdition (2002)
# Processing 137/9515: Boogie Nights (1997)
# Processing 138/9515: Total Recall (1990)
# Processing 139/9515: Bo Burnham: Inside (2021)
# Processing 140/9515: Snowpiercer (2013)
# Processing 141/9515: Circus of Books (2019)
# Processing 142/9515: Tallulah (2016)
# Processing 143/9515: The Conjuring 2 (2016)
# Processing 144/9515: They'll Love Me When I'm Dead (2018)
# Processing 145/9515: Nocturnal Animals (2016)
# Processing 146/9515: Get Me Roger Stone (2017)
# Processing 147/9515: Hachi: A Dog's Tale (2009)
# Processing 148/9515: Dances with Wolves (1990)
# Processing 149/9515: Udta Punjab (2016)
# Processing 150/9515: Bareilly's Barfi (2017)
# Processed 150 movies. Pausing for rate limiting...
# Processing 151/9515: Divines (2016)
# Processing 152/9515: Maktub (2017)
# Processing 153/9515: Ittefaq (2017)
# Processing 154/9515: Hannah Gadsby: Nanette (2018)
# Processing 155/9515: Ali Wong: Hard Knock Wife (2018)
# Processing 156/9515: Seven Pounds (2008)
# Processing 157/9515: Uncut Gems (2019)
# Processing 158/9515: The Kindergarten Teacher (2018)
# Processing 159/9515: Les Misérables (2012)
# Processing 160/9515: The Sky Is Pink (2019)
# Processing 161/9515: Next Gen (2018)
# Processing 162/9515: Tom Segura: Disgraceful (2018)
# Processing 163/9515: My Happy Family (2017)
# Processing 164/9515: The American Meme (2018)
# Processing 165/9515: Badla (2019)
# Processing 166/9515: Okko's Inn (2018)
# Processing 167/9515: The Willoughbys (2020)
# Processing 168/9515: Hunt for the Wilderpeople (2016)
# Processing 169/9515: Stardust (2007)
# Processing 170/9515: Wheelman (2017)
# Processing 171/9515: The Artist (2011)
# Processing 172/9515: On My Skin (2018)
# Processing 173/9515: Gaga: Five Foot Two (2017)
# Processing 174/9515: Hugo (2011)
# Processing 175/9515: The Impossible (2012)
# Processing 176/9515: War Dogs (2016)
# Processing 177/9515: Ip Man (2008)
# Processing 178/9515: The Speed Cubers (2020)
# Processing 179/9515: Kung Fu Panda 2 (2011)
# Processing 180/9515: The Dirt (2019)
# Processing 181/9515: Andhadhun (2018)
# Processing 182/9515: Atlantics (2019)
# Processing 183/9515: 37 Seconds (2019)
# Processing 184/9515: El Camino: A Breaking Bad Movie (2019)
# Processing 185/9515: Underworld (2003)
# Processing 186/9515: The Ring (2002)
# Processing 187/9515: Hold the Dark (2018)
# Processing 188/9515: The Karate Kid (1984)
# Processing 189/9515: Quincy (2018)
# Processing 190/9515: The Patriot (2000)
# Processing 191/9515: Get In (2019)
# Processing 192/9515: ZZ Top: That Little Ol' Band From Texas (2019)
# Processing 193/9515: Jerry Before Seinfeld (2017)
# Processing 194/9515: Mike Birbiglia: The New One (2019)
# Processing 195/9515: A Silent Voice: The Movie (2016)
# Processing 196/9515: Klaus (2019)
# Processing 197/9515: Snowden (2016)
# Processing 198/9515: Nick Kroll & John Mulaney: Oh, Hello on Broadway (2017)
# Processing 199/9515: What's Eating Gilbert Grape (1993)
# Processing 200/9515: The Da Vinci Code (2006)
# Processed 200 movies. Pausing for rate limiting...
# Processing 201/9515: Stranger Than Fiction (2006)
# Processing 202/9515: Don 2 (2011)
# Processing 203/9515: Elena (2013)
# Processing 204/9515: Real Steel (2011)
# Processing 205/9515: The Founder (2017)
# Processing 206/9515: Stargate (1994)
# Processing 207/9515: Shirkers (2018)
# Processing 208/9515: Chef (2014)
# Processing 209/9515: Fire in the Blood (2013)
# Processing 210/9515: Austin Powers: International Man of Mystery (1997)
# Processing 211/9515: Miles Davis: Birth of the Cool (2019)
# Processing 212/9515: Insidious (2010)
# Processing 213/9515: Screwball (2019)
# Processing 214/9515: The Old Guard (2020)
# Processing 215/9515: Rango (2011)
# Processing 216/9515: Before I Wake (2016)
# Processing 217/9515: The Disaster Artist (2017)
# Processing 218/9515: Fruitvale Station (2013)
# Processing 219/9515: The Florida Project (2017)
# Processing 220/9515: Behind the Curve (2018)
# Processing 221/9515: Lawless (2012)
# Processing 222/9515: Errementari: The Blacksmith and the Devil (2018)
# Processing 223/9515: Audrie & Daisy (2016)
# Processing 224/9515: Quantum of Solace (2008)
# Processing 225/9515: The Master (2012)
# Processing 226/9515: Layer Cake (2004)
# Processing 227/9515: Flipped (2010)
# Processing 228/9515: Steve Martin and Martin Short: An Evening You Will Forget for the Rest of Your Life (2018)
# Processing 229/9515: Friends with Benefits (2011)
# Processing 230/9515: Tig (2015)
# Processing 231/9515: Roll Red Roll (2019)
# Processing 232/9515: Enola Holmes (2020)
# Processing 233/9515: PK (2015)
# Processing 234/9515: Good Time (2017)
# Processing 235/9515: The Next Three Days (2010)
# Processing 236/9515: Miracle in Cell No. 7 (2019)
# Processing 237/9515: Like Stars on Earth (2007)
# Processing 238/9515: Trixie Mattel: Moving Parts (2019)
# Processing 239/9515: Talaash (2012)
# Processing 240/9515: Evelyn (2019)
# Processing 241/9515: I Am Sam (2001)
# Processing 242/9515: In the Shadow of the Moon (2019)
# Processing 243/9515: Neon Genesis Evangelion: The End of Evangelion (1997)
# Processing 244/9515: Memoirs of a Geisha (2005)
# Processing 245/9515: Mad Max (1979)
# Processing 246/9515: John Leguizamo's Latin History for Morons (2018)
# Processing 247/9515: And Breathe Normally (2018)
# Processing 248/9515: The Killing of a Sacred Deer (2017)
# Processing 249/9515: Angels & Demons (2009)
# Processing 250/9515: Smoke & Mirrors (2016)
# Processed 250 movies. Pausing for rate limiting...
# Processing 251/9515: Bright (2017)
# Processing 252/9515: Yes Man (2008)
# Processing 253/9515: Murder Mystery (2019)
# Processing 254/9515: Pink (2016)
# Processing 255/9515: The Photographer of Mauthausen (2018)
# Processing 256/9515: Midnight Run (1988)
# Processing 257/9515: Flavors of Youth (2018)
# Processing 258/9515: 13th (2016)
# Processing 259/9515: Ravenous (2017)
# Processing 260/9515: Austin Powers: The Spy Who Shagged Me (1999)
# Processing 261/9515: The Life of David Gale (2003)
# Processing 262/9515: Tramps (2016)
# Processing 263/9515: The Girl Next Door (2004)
# Processing 264/9515: The Two Popes (2019)
# Processing 265/9515: The Wandering Earth (2019)
# Processing 266/9515: Just Another Love Story (2007)
# Processing 267/9515: Eye for an Eye (2019)
# Processing 268/9515: Patton Oswalt: Annihilation (2017)
# Processing 269/9515: Joan Didion: The Center Will Not Hold (2017)
# Processing 270/9515: Steve Jobs (2015)
# Processing 271/9515: White Fang (2018)
# Processing 272/9515: A Monster Calls (2016)
# Processing 273/9515: Olympus Has Fallen (2013)
# Processing 274/9515: Talladega Nights: The Ballad of Ricky Bobby (2006)
# Processing 275/9515: The Time Traveler's Wife (2009)
# Processing 276/9515: State of Play (2009)
# Processing 277/9515: The Outlaw Josey Wales (1976)
# Processing 278/9515: The Bank Job (2008)
# Processing 279/9515: Miss Sloane (2016)
# Processing 280/9515: Unknown (2011)
# Processing 281/9515: 6 Underground (2019)
# Processing 282/9515: Uncorked (2020)
# Processing 283/9515: Petta (2019)
# Processing 284/9515: Justin Timberlake + The Tennessee Kids (2016)
# Processing 285/9515: My Fair Lady (1964)
# Processing 286/9515: Bikram: Yogi, Guru, Predator (2019)
# Processing 287/9515: A Futile and Stupid Gesture (2018)
# Processing 288/9515: The Dig (2021)
# Processing 289/9515: Legally Blonde (2001)
# Processing 290/9515: Legend (2015)
# Processing 291/9515: Notes on Blindness (2016)
# Processing 292/9515: When We First Met (2018)
# Processing 293/9515: Best Worst Thing That Ever Could Have Happened... (2016)
# Processing 294/9515: Imperial Dreams (2014)
# Processing 295/9515: Black Mirror: Bandersnatch (2018)
# Processing 296/9515: Queen (2013)
# Processing 297/9515: Joshua: Teenager vs. Superpower (2017)
# Processing 298/9515: Air Force One (1997)
# Processing 299/9515: Shot Caller (2017)
# Processing 300/9515: What Dreams May Come (1998)
# Processed 300 movies. Pausing for rate limiting...
# Processing 301/9515: Angel Has Fallen (2019)
# Processing 302/9515: Crimson Peak (2015)
# Processing 303/9515: Lemony Snicket's A Series of Unfortunate Events (2004)
# Processing 304/9515: The Red Sea Diving Resort (2019)
# Processing 305/9515: The Angel (2018)
# Processing 306/9515: Army of the Dead (2021)
# Processing 307/9515: Madagascar 3: Europe's Most Wanted (2012)
# Processing 308/9515: Icarus (2017)
# Processing 309/9515: Collateral Beauty (2016)
# Processing 310/9515: The Danish Girl (2015)
# Processing 311/9515: Green Zone (2010)
# Processing 312/9515: John Mulaney: New in Town (2012)
# Processing 313/9515: Strong Island (2017)
# Processing 314/9515: The White Tiger (2021)
# Processing 315/9515: Defiance (2008)
# Processing 316/9515: A Fortunate Man (2018)
# Processing 317/9515: The Death of Stalin (2017)
# Processing 318/9515: 2012 (2009)
# Processing 319/9515: Underworld: Awakening (2012)
# Processing 320/9515: Philomena (2013)
# Processing 321/9515: Sanju (2018)
# Processing 322/9515: Nappily Ever After (2018)
# Processing 323/9515: I Care a Lot (2021)
# Processing 324/9515: The Butler (2013)
# Processing 325/9515: Qarib Qarib Singlle (2017)
# Processing 326/9515: A Single Man (2009)
# Processing 327/9515: Home (2015)
# Processing 328/9515: Zack and Miri Make a Porno (2008)
# Processing 329/9515: Seeing Allred (2018)
# Processing 330/9515: Dostana (2008)
# Processing 331/9515: Remember Me (2010)
# Processing 332/9515: Underworld: Rise of the Lycans (2009)
# Processing 333/9515: The Lovely Bones (2009)
# Processing 334/9515: Madagascar: Escape 2 Africa (2008)
# Processing 335/9515: No Strings Attached (2011)
# Processing 336/9515: Heroin(e) (2017)
# Processing 337/9515: A Ghost Story (2017)
# Processing 338/9515: Safety Not Guaranteed (2012)
# Processing 339/9515: Game Over (2019)
# Processing 340/9515: Peppermint (2018)
# Processing 341/9515: Have a Good Trip: Adventures in Psychedelics (2020)
# Processing 342/9515: Beasts of No Nation (2015)
# Processing 343/9515: Extinction (2018)
# Processing 344/9515: Nobody Knows I'm Here (2020)
# Processing 345/9515: ARQ (2016)
# Processing 346/9515: Ali's Wedding (2017)
# Processing 347/9515: Bo Burnham: Make Happy (2016)
# Processing 348/9515: Mank (2020)
# Processing 349/9515: Extremely Wicked, Shockingly Evil and Vile (2019)
# Processing 350/9515: Due Date (2010)
# Processed 350 movies. Pausing for rate limiting...
# Processing 351/9515: Between Two Ferns: The Movie (2019)
# Processing 352/9515: Ip Man 2 (2010)
# Processing 353/9515: Mirage (2018)
# Processing 354/9515: Puss in Boots (2011)
# Processing 355/9515: Austin Powers in Goldmember (2002)
# Processing 356/9515: The Kissing Booth (2018)
# Processing 357/9515: Hush (2016)
# Processing 358/9515: Lost Bullet (2020)
# Processing 359/9515: Dil Chahta Hai (2001)
# Processing 360/9515: Election (1999)
# Processing 361/9515: Soni (2019)
# Processing 362/9515: Bāhubali: The Beginning (2015)
# Processing 363/9515: Killing Them Softly (2012)
# Processing 364/9515: Swordfish (2001)
# Processing 365/9515: Wish Dragon (2021)
# Processing 366/9515: Raees (2017)
# Processing 367/9515: Let It Snow (2019)
# Processing 368/9515: The Babysitter: Killer Queen (2020)
# Processing 369/9515: Hardcore Henry (2015)
# Processing 370/9515: Tig Notaro: Happy To Be Here (2018)
# Processing 371/9515: Spelling the Dream (2020)
# Processing 372/9515: Knock Down the House (2019)
# Processing 373/9515: Resident Evil: Extinction (2007)
# Processing 374/9515: Polar (2019)
# Processing 375/9515: Saving Capitalism (2017)
# Processing 376/9515: The Untold Tales of Armistead Maupin (2017)
# Processing 377/9515: The Mitchells vs. The Machines (2021)
# Processing 378/9515: Spenser Confidential (2020)
# Processing 379/9515: Psychokinesis (2018)
# Processing 380/9515: Monsters vs Aliens (2009)
# Processing 381/9515: Twilight (2008)
# Processing 382/9515: Self/less (2015)
# Processing 383/9515: The Highwaymen (2019)
# Processing 384/9515: ParaNorman (2012)
# Processing 385/9515: Holidate (2020)
# Processing 386/9515: Fear Street Part Two: 1978 (2021)
# Processing 387/9515: Pee-wee's Big Holiday (2016)
# Processing 388/9515: Gunpowder Milkshake (2021)
# Processing 389/9515: Michael Bolton's Big, Sexy Valentine's Day Special (2017)
# Processing 390/9515: I Am Not Your Negro (2017)
# Processing 391/9515: Midnight Special (2016)
# Processing 392/9515: Layla M. (2016)
# Processing 393/9515: Homefront (2013)
# Processing 394/9515: The Squid and the Whale (2005)
# Processing 395/9515: Comedian (2002)
# Processing 396/9515: No Escape (2015)
# Processing 397/9515: Mercury 13 (2018)
# Processing 398/9515: The Professor and the Madman (2019)
# Processing 399/9515: Asperger's Are Us (2016)
# Processing 400/9515: The Garden of Words (2013)
# Processed 400 movies. Pausing for rate limiting...
# Processing 401/9515: Fractured (2019)
# Processing 402/9515: The Queen (2006)
# Processing 403/9515: The Whole Nine Yards (2000)
# Processing 404/9515: E-Team (2014)
# Processing 405/9515: The Discovery (2017)
# Processing 406/9515: The Strangers (2008)
# Processing 407/9515: Penguins of Madagascar (2014)
# Processing 408/9515: She's Out of My League (2010)
# Processing 409/9515: Voyeur (2017)
# Processing 410/9515: It Comes at Night (2017)
# Processing 411/9515: The Manchurian Candidate (2004)
# Processing 412/9515: Bon Cop Bad Cop 2 (2017)
# Processing 413/9515: Hot Rod (2007)
# Processing 414/9515: The BFG (2016)
# Processing 415/9515: Sunday's Illness (2018)
# Processing 416/9515: The Lorax (2012)
# Processing 417/9515: Win It All (2017)
# Processing 418/9515: Mile 22 (2018)
# Processing 419/9515: Tenacious D in The Pick of Destiny (2006)
# Processing 420/9515: The Sum of All Fears (2002)
# Processing 421/9515: G.O.R.A. (2004)
# Processing 422/9515: The Perfect Date (2019)
# Processing 423/9515: Code 8 (2019)
# Processing 424/9515: Cowspiracy: The Sustainability Secret (2014)
# Processing 425/9515: Life As We Know It (2010)
# Processing 426/9515: American Assassin (2017)
# Processing 427/9515: August: Osage County (2013)
# Processing 428/9515: Kuch Kuch Hota Hai (1998)
# Processing 429/9515: Who Am I (2014)
# Processing 430/9515: Free State of Jones (2016)
# Processing 431/9515: Beast Stalker (2008)
# Processing 432/9515: Dark Skies (2013)
# Processing 433/9515: Safe Haven (2013)
# Processing 434/9515: Bāhubali 2: The Conclusion (2017)
# Processing 435/9515: Outlaw King (2018)
# Processing 436/9515: Cloudy with a Chance of Meatballs 2 (2013)
# Processing 437/9515: Turbo (2013)
# Processing 438/9515: G.I. Joe: The Rise of Cobra (2009)
# Processing 439/9515: Horns (2013)
# Processing 440/9515: Drishyam (2015)
# Processing 441/9515: Triple Frontier (2019)
# Processing 442/9515: Hail, Caesar! (2016)
# Processing 443/9515: The Ice Road (2021)
# Processing 444/9515: Monster House (2006)
# Processing 445/9515: Freaks (2019)
# Processing 446/9515: Felon (2008)
# Processing 447/9515: Horse Girl (2020)
# Processing 448/9515: A Christmas Prince (2017)
# Processing 449/9515: Hillbilly Elegy (2020)
# Processing 450/9515: American Ultra (2015)
# Processed 450 movies. Pausing for rate limiting...
# Processing 451/9515: First Match (2018)
# Processing 452/9515: The Pelican Brief (1993)
# Processing 453/9515: The Tourist (2010)
# Processing 454/9515: The Dawn Wall (2017)
# Processing 455/9515: I'm Thinking of Ending Things (2020)
# Processing 456/9515: Shutter (2004)
# Processing 457/9515: Surf's Up (2007)
# Processing 458/9515: The Twilight Saga: Breaking Dawn - Part 2 (2012)
# Processing 459/9515: Jagga Jasoos (2017)
# Processing 460/9515: The Burial of Kojo (2018)
# Processing 461/9515: My Best Friend's Wedding (1997)
# Processing 462/9515: Bee Movie (2007)
# Processing 463/9515: Seoul Searching (2015)
# Processing 464/9515: Before I Fall (2017)
# Processing 465/9515: The Babysitter (2017)
# Processing 466/9515: After (2019)
# Processing 467/9515: As Above, So Below (2014)
# Processing 468/9515: Bo Burnham: What. (2013)
# Processing 469/9515: Stree (2018)
# Processing 470/9515: Velvet Buzzsaw (2019)
# Processing 471/9515: Savages (2012)
# Processing 472/9515: Jupiter Ascending (2015)
# Processing 473/9515: Spectral (2016)
# Processing 474/9515: Resident Evil: Afterlife (2010)
# Processing 475/9515: Accepted (2006)
# Processing 476/9515: Live Twice, Love Once (2019)
# Processing 477/9515: Iliza Shlesinger: Elder Millennial (2018)
# Processing 478/9515: Zindagi Na Milegi Dobara (2011)
# Processing 479/9515: Free Fire (2017)
# Processing 480/9515: Soorma (2018)
# Processing 481/9515: The Zookeeper's Wife (2017)
# Processing 482/9515: Time Share (2018)
# Processing 483/9515: The Outpost (2019)
# Processing 484/9515: Kabir Singh (2019)
# Processing 485/9515: Homecoming: A Film by Beyoncé (2019)
# Processing 486/9515: Jerry Seinfeld: 23 Hours to Kill (2020)
# Processing 487/9515: Ip Man 4: The Finale (2019)
# Processing 488/9515: The Laundromat (2019)
# Processing 489/9515: The 12th Man (2017)
# Processing 490/9515: Bad Trip (2020)
# Processing 491/9515: Mr. Peabody & Sherman (2014)
# Processing 492/9515: Ip Man 3 (2015)
# Processing 493/9515: Rang De Basanti (2006)
# Processing 494/9515: The Midnight Sky (2020)
# Processing 495/9515: Mr. Right (2016)
# Processing 496/9515: White Christmas (1954)
# Processing 497/9515: Synchronic (2020)
# Processing 498/9515: Adrift (2018)
# Processing 499/9515: The Game Changers (2019)
# Processing 500/9515: Michelle Wolf: Joke Show (2019)
# Processed 500 movies. Pausing for rate limiting...
# Processing 501/9515: Da 5 Bloods (2020)
# Processing 502/9515: The American (2010)
# Processing 503/9515: The Best of Enemies (2019)
# Processing 504/9515: Forgotten (2017)
# Processing 505/9515: I Don't Feel at Home in This World Anymore (2017)
# Processing 506/9515: Lupin the Third: The Castle of Cagliostro (1979)
# Processing 507/9515: Never Back Down (2008)
# Processing 508/9515: Fear Street: 1666 (2021)
# Processing 509/9515: Zathura: A Space Adventure (2005)
# Processing 510/9515: Faith, Hope & Love (2019)
# Processing 511/9515: 2 States (2014)
# Processing 512/9515: Grass is Greener (2019)
# Processing 513/9515: May the Devil Take You (2018)
# Processing 514/9515: Double Jeopardy (1999)
# Processing 515/9515: Ava (2020)
# Processing 516/9515: Barfi! (2012)
# Processing 517/9515: Barry (2016)
# Processing 518/9515: Go! (2020)
# Processing 519/9515: Everybody's Fine (2009)
# Processing 520/9515: Monty Python Live at the Hollywood Bowl (1982)
# Processing 521/9515: Parker (2013)
# Processing 522/9515: The Karate Kid Part II (1986)
# Processing 523/9515: System Crasher (2019)
# Processing 524/9515: Under Siege (1992)
# Processing 525/9515: Brain on Fire (2017)
# Processing 526/9515: The Butterfly's Dream (2013)
# Processing 527/9515: The Wrong Missy (2020)
# Processing 528/9515: Battle: Los Angeles (2011)
# Processing 529/9515: Pari (2018)
# Processing 530/9515: The Beguiled (2017)
# Processing 531/9515: Batman: The Killing Joke (2016)
# Processing 532/9515: Sex Drive (2008)
# Processing 533/9515: Mosul (2020)
# Processing 534/9515: Pokémon the Movie: The Power of Us (2018)
# Processing 535/9515: Underdogs (2013)
# Processing 536/9515: The Little Rascals (1994)
# Processing 537/9515: Fun with Dick and Jane (2005)
# Processing 538/9515: Ballerina (2016)
# Processing 539/9515: Hasan Minhaj: Homecoming King (2017)
# Processing 540/9515: An Easy Girl (2019)
# Processing 541/9515: Highway (2014)
# Processing 542/9515: The Book of Henry (2017)
# Processing 543/9515: Reversing Roe (2018)
# Processing 544/9515: The Clovehitch Killer (2018)
# Processing 545/9515: There's Something in the Water (2019)
# Processing 546/9515: Stuart Little (1999)
# Processing 547/9515: Barakah Meets Barakah (2016)
# Processing 548/9515: Starsky & Hutch (2004)
# Processing 549/9515: Loving (2016)
# Processing 550/9515: Haider (2014)
# Processed 550 movies. Pausing for rate limiting...
# Processing 551/9515: The Twilight Saga: Eclipse (2010)
# Processing 552/9515: Triple 9 (2016)
# Processing 553/9515: Spanglish (2004)
# Processing 554/9515: The Spiderwick Chronicles (2008)
# Processing 555/9515: Kahaani (2012)
# Processing 556/9515: Lady J (2018)
# Processing 557/9515: The Interpreter (2005)
# Processing 558/9515: Frankenstein's Monster's Monster, Frankenstein (2019)
# Processing 559/9515: Not Another Teen Movie (2001)
# Processing 560/9515: The Cloverfield Paradox (2018)
# Processing 561/9515: Disclosure (2020)
# Processing 562/9515: Hot Girls Wanted (2015)
# Processing 563/9515: Dead Man Down (2013)
# Processing 564/9515: Fear Street: 1994 (2021)
# Processing 565/9515: Kill the Irishman (2011)
# Processing 566/9515: Set It Up (2018)
# Processing 567/9515: Case 39 (2009)
# Processing 568/9515: Outside the Wire (2021)
# Processing 569/9515: Steal a Pencil for Me (2007)
# Processing 570/9515: Project Power (2020)
# Processing 571/9515: High Strung Free Dance (2018)
# Processing 572/9515: The Twilight Saga: Breaking Dawn - Part 1 (2011)
# Processing 573/9515: Marc Maron: Too Real (2017)
# Processing 574/9515: The Polka King (2017)
# Processing 575/9515: 6 Balloons (2018)
# Processing 576/9515: Amanda Knox (2016)
# Processing 577/9515: At Eternity's Gate (2018)
# Processing 578/9515: Anon (2018)
# Processing 579/9515: 3 Days to Kill (2014)
# Processing 580/9515: To the Bone (2017)
# Processing 581/9515: Trollhunters: Rise of the Titans (2021)
# Processing 582/9515: Mowgli: Legend of the Jungle (2018)
# Processing 583/9515: Mother's Day (2016)
# Processing 584/9515: Mortal Kombat (1995)
# Processing 585/9515: Creep (2014)
# Processing 586/9515: Death to 2020 (2020)
# Processing 587/9515: Operation Finale (2018)
# Processing 588/9515: The Great Hack (2019)
# Processing 589/9515: The Land of Steady Habits (2018)
# Processing 590/9515: Suffragette (2015)
# Processing 591/9515: Wildlife (2018)
# Processing 592/9515: War Machine (2017)
# Processing 593/9515: Bending the Arc (2017)
# Processing 594/9515: Kill the Messenger (2014)
# Processing 595/9515: Feminists: What Were They Thinking? (2018)
# Processing 596/9515: If Anything Happens I Love You (2020)
# Processing 597/9515: Nobody Speak: Trials of the Free Press (2017)
# Processing 598/9515: Sand Castle (2017)
# Processing 599/9515: The Forest of Love (2019)
# Processing 600/9515: Kabhi Alvida Naa Kehna (2006)
# Processed 600 movies. Pausing for rate limiting...
# Processing 601/9515: Fatherhood (2021)
# Processing 602/9515: Our Idiot Brother (2011)
# Processing 603/9515: Quién te cantará (2018)
# Processing 604/9515: Takers (2010)
# Processing 605/9515: Udaan (2010)
# Processing 606/9515: City of Joy (2016)
# Processing 607/9515: Under the Shadow (2016)
# Processing 608/9515: The Silence of Others (2019)
# Processing 609/9515: Nacho Libre (2006)
# Processing 610/9515: Ninja Assassin (2009)
# Processing 611/9515: The Twilight Saga: New Moon (2009)
# Processing 612/9515: Rocks (2020)
# Processing 613/9515: Step Up Revolution (2012)
# Processing 614/9515: Giving Voice (2020)
# Processing 615/9515: Like Father (2018)
# Processing 616/9515: Eddie Murphy Raw (1987)
# Processing 617/9515: Berserk: The Golden Age Arc III - The Advent (2013)
# Processing 618/9515: Aval (2017)
# Processing 619/9515: The Promise (2016)
# Processing 620/9515: Prospect (2018)
# Processing 621/9515: Ne Zha (2019)
# Processing 622/9515: Bad Genius (2017)
# Processing 623/9515: Burning Sands (2017)
# Processing 624/9515: Ludo (2020)
# Processing 625/9515: Eat Pray Love (2010)
# Processing 626/9515: Circle (2015)
# Processing 627/9515: Rolling Thunder Revue: A Bob Dylan Story by Martin Scorsese (2019)
# Processing 628/9515: Dovlatov (2018)
# Processing 629/9515: Lakshya (2004)
# Processing 630/9515: American Murder: The Family Next Door (2020)
# Processing 631/9515: Jab We Met (2007)
# Processing 632/9515: Kuchh Bheege Alfaaz (2018)
# Processing 633/9515: John Mulaney: The Comeback Kid (2015)
# Processing 634/9515: Apostle (2018)
# Processing 635/9515: After We Collided (2020)
# Processing 636/9515: Mystic Pizza (1988)
# Processing 637/9515: Middle Men (2009)
# Processing 638/9515: To All the Boys: P.S. I Still Love You (2020)
# Processing 639/9515: Malang (2020)
# Processing 640/9515: Someone Great (2019)
# Processing 641/9515: Time Trap (2017)
# Processing 642/9515: In This Corner of the World (2016)
# Processing 643/9515: C/o Kancharapalem (2018)
# Processing 644/9515: Agneepath (1990)
# Processing 645/9515: The Package (2018)
# Processing 646/9515: Tau (2018)
# Processing 647/9515: Your Highness (2011)
# Processing 648/9515: Alexander (2004)
# Processing 649/9515: Rurouni Kenshin: The Final (2021)
# Processing 650/9515: Bill Burr: I'm Sorry You Feel That Way (2014)
# Processed 650 movies. Pausing for rate limiting...
# Processing 651/9515: Berserk: The Golden Age Arc I - The Egg of the King (2012)
# Processing 652/9515: All the Bright Places (2020)
# Processing 653/9515: Streets of Fire (1984)
# Processing 654/9515: Sleepless (2017)
# Processing 655/9515: An Egyptian Story (1982)
# Processing 656/9515: Major Grom: Plague Doctor (2021)
# Processing 657/9515: Struggle: The Life and Lost Art of Szukalski (2018)
# Processing 658/9515: Seaspiracy (2021)
# Processing 659/9515: Wish I Was Here (2014)
# Processing 660/9515: Moxie (2021)
# Processing 661/9515: 18 Presents (2020)
# Processing 662/9515: Oxygen (2021)
# Processing 663/9515: Private Life (2018)
# Processing 664/9515: The Grandmaster (2013)
# Processing 665/9515: Home Again (2017)
# Processing 666/9515: Athlete A (2020)
# Processing 667/9515: The Outsider (2018)
# Processing 668/9515: The Fourth Kind (2009)
# Processing 669/9515: Bastille Day (2016)
# Processing 670/9515: The Whole Truth (2016)
# Processing 671/9515: Ibiza (2018)
# Processing 672/9515: Sabotage (2014)
# Processing 673/9515: Penguin Bloom (2021)
# Processing 674/9515: The Kissing Booth 2 (2020)
# Processing 675/9515: Kingsglaive: Final Fantasy XV (2016)
# Processing 676/9515: Mirai (2018)
# Processing 677/9515: Child's Play 2 (1990)
# Processing 678/9515: World Trade Center (2006)
# Processing 679/9515: OMG: Oh My God! (2012)
# Processing 680/9515: A Private War (2018)
# Processing 681/9515: Get on Up (2014)
# Processing 682/9515: The Possession (2012)
# Processing 683/9515: The Angry Birds Movie 2 (2019)
# Processing 684/9515: Stowaway (2021)
# Processing 685/9515: Bill Burr: You People Are All The Same (2012)
# Processing 686/9515: Four Christmases (2008)
# Processing 687/9515: Bombay Talkies (2013)
# Processing 688/9515: Vampire Academy (2014)
# Processing 689/9515: Brick Mansions (2014)
# Processing 690/9515: Kingdom: Ashin of the North (2021)
# Processing 691/9515: Andaz Apna Apna (1994)
# Processing 692/9515: Emicida: AmarElo - It's All for Yesterday (2020)
# Processing 693/9515: Blue Miracle (2021)
# Processing 694/9515: Holding the Man (2015)
# Processing 695/9515: Small Town Crime (2018)
# Processing 696/9515: Ek Ladki Ko Dekha Toh Aisa Laga (2019)
# Processing 697/9515: First They Killed My Father (2017)
# Processing 698/9515: Rising Phoenix (2020)
# Processing 699/9515: The Wolf's Call (2019)
# Processing 700/9515: Paan Singh Tomar (2012)
# Processed 700 movies. Pausing for rate limiting...
# Processing 701/9515: John Mulaney & The Sack Lunch Bunch (2019)
# Processing 702/9515: Seventh Son (2015)
# Processing 703/9515: The Death of Mr. Lazarescu (2005)
# Processing 704/9515: The Occupant (2020)
# Processing 705/9515: The Body Remembers When the World Broke Open (2019)
# Processing 706/9515: The Woman in the Window (2021)
# Processing 707/9515: Berlin Syndrome (2017)
# Processing 708/9515: What the Health (2017)
# Processing 709/9515: The Runaways (2010)
# Processing 710/9515: Kodachrome (2017)
# Processing 711/9515: Croupier (1998)
# Processing 712/9515: The Smurfs (2011)
# Processing 713/9515: Muppets Most Wanted (2014)
# Processing 714/9515: Creep 2 (2017)
# Processing 715/9515: Mandela: Long Walk to Freedom (2013)
# Processing 716/9515: Toilet: A Love Story (2017)
# Processing 717/9515: The Square (2013)
# Processing 718/9515: Jerry Seinfeld: I'm Telling You for the Last Time (1998)
# Processing 719/9515: Roxanne, Roxanne (2017)
# Processing 720/9515: Riphagen The Untouchable (2016)
# Processing 721/9515: Dear Zindagi (2016)
# Processing 722/9515: Vizontele (2001)
# Processing 723/9515: Good on Paper (2021)
# Processing 724/9515: Ophelia (2019)
# Processing 725/9515: Black Sea (2014)
# Processing 726/9515: Girl (2018)
# Processing 727/9515: Irreplaceable You (2018)
# Processing 728/9515: The Do-Over (2016)
# Processing 729/9515: Metallica: Some Kind of Monster (2004)
# Processing 730/9515: Handsome Devil (2017)
# Processing 731/9515: Unfriended (2015)
# Processing 732/9515: Visaranai (2016)
# Processing 733/9515: Been So Long (2018)
# Processing 734/9515: Yes Day (2021)
# Processing 735/9515: Blood Red Sky (2021)
# Processing 736/9515: The Bleeding Edge (2018)
# Processing 737/9515: Tread (2020)
# Processing 738/9515: Berserk: The Golden Age Arc II - The Battle for Doldrey (2012)
# Processing 739/9515: Kevin Hart: Irresponsible (2019)
# Processing 740/9515: In the Tall Grass (2019)
# Processing 741/9515: Wadjda (2012)
# Processing 742/9515: Ferry (2021)
# Processing 743/9515: The Heartbreak Kid (2007)
# Processing 744/9515: Fools Rush In (1997)
# Processing 745/9515: Wild Child (2008)
# Processing 746/9515: The Lovebirds (2020)
# Processing 747/9515: Machete Kills (2013)
# Processing 748/9515: Sergio (2020)
# Processing 749/9515: The Last Letter From Your Lover (2021)
# Processing 750/9515: Kursk (2018)
# Processed 750 movies. Pausing for rate limiting...
# Processing 751/9515: Then Came You (2019)
# Processing 752/9515: Gantz:O (2016)
# Processing 753/9515: Jenny Slate: Stage Fright (2019)
# Processing 754/9515: Taylor Swift: Reputation Stadium Tour (2018)
# Processing 755/9515: Jodhaa Akbar (2008)
# Processing 756/9515: Red Joan (2018)
# Processing 757/9515: Amateur (2018)
# Processing 758/9515: What a Girl Wants (2003)
# Processing 759/9515: Quigley Down Under (1990)
# Processing 760/9515: Cop Out (2010)
# Processing 761/9515: Mindhorn (2016)
# Processing 762/9515: Katt Williams: Great America (2018)
# Processing 763/9515: Lingua Franca (2020)
# Processing 764/9515: Abduction (2011)
# Processing 765/9515: Copenhagen (2014)
# Processing 766/9515: High Flying Bird (2019)
# Processing 767/9515: Free to Play (2014)
# Processing 768/9515: Life of Crime (2013)
# Processing 769/9515: A Very Murray Christmas (2015)
# Processing 770/9515: The Silence (2019)
# Processing 771/9515: Sarah's Key (2010)
# Processing 772/9515: Abducted in Plain Sight (2018)
# Processing 773/9515: Winchester (2018)
# Processing 774/9515: Our Souls at Night (2017)
# Processing 775/9515: The Karate Kid Part III (1989)
# Processing 776/9515: Haseen Dillruba (2021)
# Processing 777/9515: SampleThis (2013)
# Processing 778/9515: Bride of Chucky (1998)
# Processing 779/9515: Christine (2016)
# Processing 780/9515: Secret Superstar (2017)
# Processing 781/9515: The Lonely Island Presents: The Unauthorized Bash Brothers Experience (2019)
# Processing 782/9515: WHAT DID JACK DO? (2017)
# Processing 783/9515: Blue Jay (2016)
# Processing 784/9515: Deidra & Laney Rob a Train (2017)
# Processing 785/9515: Hari Kondabolu: Warn Your Relatives (2018)
# Processing 786/9515: Close (2019)
# Processing 787/9515: Sir (2018)
# Processing 788/9515: Congo (1995)
# Processing 789/9515: The Prom (2020)
# Processing 790/9515: Naruto Shippuden the Movie (2007)
# Processing 791/9515: The Bling Ring (2013)
# Processing 792/9515: Greater (2016)
# Processing 793/9515: 07:19 (2016)
# Processing 794/9515: Neal Brennan: 3 Mics (2017)
# Processing 795/9515: In the Family (2017)
# Processing 796/9515: The Awakening of Motti Wolkenbruch (2018)
# Processing 797/9515: Beats (2019)
# Processing 798/9515: Lost Girls (2020)
# Processing 799/9515: The Witch: Part 1. The Subversion (2018)
# Processing 800/9515: Don (2006)
# Processed 800 movies. Pausing for rate limiting...
# Processing 801/9515: A Little Chaos (2015)
# Processing 802/9515: Dennis the Menace (1993)
# Processing 803/9515: iBoy (2017)
# Processing 804/9515: Rush: Beyond The Lighted Stage (2010)
# Processing 805/9515: See You Yesterday (2019)
# Processing 806/9515: Metallica: Through the Never (2013)
# Processing 807/9515: Xtreme (2021)
# Processing 808/9515: Beyond the Clouds (2018)
# Processing 809/9515: Two Distant Strangers (2020)
# Processing 810/9515: Bert Kreischer: Secret Time (2018)
# Processing 811/9515: To All the Boys: Always and Forever (2021)
# Processing 812/9515: Breaking Boundaries: The Science of Our Planet (2021)
# Processing 813/9515: Yes, God, Yes (2019)
# Processing 814/9515: The Long Riders (1980)
# Processing 815/9515: Shepherds and Butchers (2017)
# Processing 816/9515: Big Miracle (2012)
# Processing 817/9515: Gunjan Saxena: The Kargil Girl (2020)
# Processing 818/9515: The Invisible Guardian (2017)
# Processing 819/9515: Cop Car (2015)
# Processing 820/9515: Main Hoon Na (2004)
# Processing 821/9515: Last Breath (2019)
# Processing 822/9515: The Stepfather (2009)
# Processing 823/9515: Joe Rogan: Strange Times (2018)
# Processing 824/9515: The Sweetest Thing (2002)
# Processing 825/9515: Dil Se.. (1998)
# Processing 826/9515: Thunder Force (2021)
# Processing 827/9515: The Ivory Game (2016)
# Processing 828/9515: Otherhood (2019)
# Processing 829/9515: Space Sweepers (2021)
# Processing 830/9515: The Prince & Me (2004)
# Processing 831/9515: For the Love of Spock (2016)
# Processing 832/9515: The Green Inferno (2015)
# Processing 833/9515: A Babysitter's Guide to Monster Hunting (2020)
# Processing 834/9515: Fantastic Fungi (2019)
# Processing 835/9515: West Beirut (1998)
# Processing 836/9515: He Never Died (2015)
# Processing 837/9515: The Nut Job (2014)
# Processing 838/9515: Unicorn Store (2017)
# Processing 839/9515: Alex Strangelove (2018)
# Processing 840/9515: Naruto Shippuden the Movie: The Will of Fire (2009)
# Processing 841/9515: David Foster: Off the Record (2019)
# Processing 842/9515: Pihu (2018)
# Processing 843/9515: American Me (1992)
# Processing 844/9515: The Christmas Chronicles: Part Two (2020)
# Processing 845/9515: Sinister 2 (2015)
# Processing 846/9515: Don't Go Breaking My Heart (2011)
# Processing 847/9515: Black '47 (2018)
# Processing 848/9515: Mute (2018)
# Processing 849/9515: Crouching Tiger, Hidden Dragon: Sword of Destiny (2016)
# Processing 850/9515: The Ottoman Lieutenant (2017)
# Processed 850 movies. Pausing for rate limiting...
# Processing 851/9515: Teefa in Trouble (2018)
# Processing 852/9515: David Cross: Making America Great Again (2016)
# Processing 853/9515: The Last Days (1998)
# Processing 854/9515: Fred Claus (2007)
# Processing 855/9515: Sierra Burgess Is a Loser (2018)
# Processing 856/9515: Pariah (2011)
# Processing 857/9515: Cam (2018)
# Processing 858/9515: The Boys in the Band (2020)
# Processing 859/9515: Kai Po Che! (2013)
# Processing 860/9515: The Tree of Blood (2018)
# Processing 861/9515: Magic Carpet Ride (2005)
# Processing 862/9515: A Sun (2019)
# Processing 863/9515: The Mirror Has Two Faces (1996)
# Processing 864/9515: The Skin of the Wolf (2018)
# Processing 865/9515: Come Sunday (2018)
# Processing 866/9515: The Forty-Year-Old Version (2020)
# Processing 867/9515: Eli (2019)
# Processing 868/9515: Naruto the Movie: Ninja Clash in the Land of Snow (2004)
# Processing 869/9515: Tony Robbins: I Am Not Your Guru (2016)
# Processing 870/9515: Good Burger (1997)
# Processing 871/9515: Jimmy Neutron: Boy Genius (2001)
# Processing 872/9515: American Son (2019)
# Processing 873/9515: The Call (2020)
# Processing 874/9515: Nights in Rodanthe (2008)
# Processing 875/9515: Dick Johnson Is Dead (2020)
# Processing 876/9515: Maps to the Stars (2014)
# Processing 877/9515: The Hows of Us (2018)
# Processing 878/9515: Mimi (2021)
# Processing 879/9515: 100 Meters (2016)
# Processing 880/9515: The Death and Life of Marsha P. Johnson (2017)
# Processing 881/9515: No Game No Life: Zero (2017)
# Processing 882/9515: Taylor Tomlinson: Quarter-Life Crisis (2020)
# Processing 883/9515: All Day and a Night (2020)
# Processing 884/9515: Ali Wong: Baby Cobra (2016)
# Processing 885/9515: Parmanu: The Story of Pokhran (2018)
# Processing 886/9515: The Incredible Jessica James (2017)
# Processing 887/9515: The Happytime Murders (2018)
# Processing 888/9515: The Strangers: Prey at Night (2018)
# Processing 889/9515: Cradle 2 the Grave (2003)
# Processing 890/9515: Jim Gaffigan: King Baby (2009)
# Processing 891/9515: Rust Creek (2019)
# Processing 892/9515: The Smurfs 2 (2013)
# Processing 893/9515: Asmaa (2011)
# Processing 894/9515: Rock On!! (2008)
# Processing 895/9515: Fisherman’s Friends (2019)
# Processing 896/9515: Avengement (2019)
# Processing 897/9515: Other People (2016)
# Processing 898/9515: Kicking and Screaming (1995)
# Processing 899/9515: Tamasha (2015)
# Processing 900/9515: The Meddler (2016)
# Processed 900 movies. Pausing for rate limiting...
# Processing 901/9515: White Girl (2016)
# Processing 902/9515: Below Zero (2021)
# Processing 903/9515: The Climb (2017)
# Processing 904/9515: The Rachel Divide (2018)
# Processing 905/9515: 1000 Mabrouk (2009)
# Processing 906/9515: Undefeated (2011)
# Processing 907/9515: Lying and Stealing (2019)
# Processing 908/9515: Who Would You Take to a Deserted Island? (2019)
# Processing 909/9515: Richard Pryor: Live in Concert (1979)
# Processing 910/9515: Om Shanti Om (2007)
# Processing 911/9515: Year One (2009)
# Processing 912/9515: Waiting for "Superman" (2010)
# Processing 913/9515: Andhaghaaram (2020)
# Processing 914/9515: Hop (2011)
# Processing 915/9515: Coming Soon (2014)
# Processing 916/9515: The Rugrats Movie (1998)
# Processing 917/9515: Jingle Jangle: A Christmas Journey (2020)
# Processing 918/9515: Mission Blue (2014)
# Processing 919/9515: Beverly Hills Ninja (1997)
# Processing 920/9515: In a Valley of Violence (2016)
# Processing 921/9515: The Battered Bastards of Baseball (2014)
# Processing 922/9515: Inhuman Kiss (2019)
# Processing 923/9515: The Motive (2017)
# Processing 924/9515: Lust Stories (2018)
# Processing 925/9515: Beyond Skyline (2017)
# Processing 926/9515: Holiday in the Wild (2019)
# Processing 927/9515: Umrika (2015)
# Processing 928/9515: The Seven Deadly Sins: Prisoners of the Sky (2018)
# Processing 929/9515: Long Shot (2017)
# Processing 930/9515: Dev.D (2009)
# Processing 931/9515: Judd Apatow: The Return (2017)
# Processing 932/9515: Jaane Tu... Ya Jaane Na (2008)
# Processing 933/9515: Escape from Planet Earth (2012)
# Processing 934/9515: Aziz Ansari: Live at Madison Square Garden (2015)
# Processing 935/9515: Yours, Mine & Ours (2005)
# Processing 936/9515: Bully (2011)
# Processing 937/9515: Sleight (2016)
# Processing 938/9515: The Hummingbird Project (2019)
# Processing 939/9515: Game Over, Man! (2018)
# Processing 940/9515: Edge of Seventeen (1998)
# Processing 941/9515: A Christmas Prince: The Royal Wedding (2018)
# Processing 942/9515: American Outlaws (2001)
# Processing 943/9515: Jim Jefferies: Bare (2014)
# Processing 944/9515: Wake Up Sid (2009)
# Processing 945/9515: Bill Hicks: Relentless (1992)
# Processing 946/9515: Mary Magdalene (2018)
# Processing 947/9515: BLACKPINK: Light Up the Sky (2020)
# Processing 948/9515: Madras Cafe (2013)
# Processing 949/9515: Berlin Calling (2008)
# Processing 950/9515: The Titan (2018)
# Processed 950 movies. Pausing for rate limiting...
# Processing 951/9515: I Am Not an Easy Man (2018)
# Processing 952/9515: Love Off the Cuff (2017)
# Processing 953/9515: Child's Play 3 (1991)
# Processing 954/9515: Rugrats in Paris: The Movie (2000)
# Processing 955/9515: Naruto Shippuden the Movie: Bonds (2008)
# Processing 956/9515: Heneral Luna (2015)
# Processing 957/9515: Delhi Belly (2011)
# Processing 958/9515: Armed to the Teeth (2018)
# Processing 959/9515: I Am All Girls (2021)
# Processing 960/9515: Jagame Thandhiram (2021)
# Processing 961/9515: Master Z: Ip Man Legacy (2019)
# Processing 962/9515: Hubie Halloween (2020)
# Processing 963/9515: Naruto Shippuden the Movie: Blood Prison (2011)
# Processing 964/9515: Awake (2021)
# Processing 965/9515: Bulbbul (2020)
# Processing 966/9515: Malcolm & Marie (2021)
# Processing 967/9515: Fukrey (2013)
# Processing 968/9515: Furie (2019)
# Processing 969/9515: The Blue Elephant Part 2 (2019)
# Processing 970/9515: Orbiter 9 (2017)
# Processing 971/9515: Awe! (2018)
# Processing 972/9515: Our Lovers (2016)
# Processing 973/9515: Newness (2017)
# Processing 974/9515: Freak Show (2018)
# Processing 975/9515: Black or White (2014)
# Processing 976/9515: Everybody's Everything (2019)
# Processing 977/9515: The Darkest Hour (2011)
# Processing 978/9515: Headshot (2016)
# Processing 979/9515: Ratchet & Clank (2016)
# Processing 980/9515: Blind Detective (2013)
# Processing 981/9515: Capital in the Twenty-First Century (2019)
# Processing 982/9515: Rim of the World (2019)
# Processing 983/9515: America: The Motion Picture (2021)
# Processing 984/9515: The Princess Switch (2018)
# Processing 985/9515: Belgica (2016)
# Processing 986/9515: Pyaar Ka Punchnama 2 (2015)
# Processing 987/9515: Love Jones (1997)
# Processing 988/9515: Kevin Hart: Seriously Funny (2010)
# Processing 989/9515: Violet Evergarden: Eternity and the Auto Memory Doll (2019)
# Processing 990/9515: Little Monsters (1989)
# Processing 991/9515: Mucize (2015)
# Processing 992/9515: Playing for Keeps (2012)
# Processing 993/9515: #Alive (2020)
# Processing 994/9515: Finding 'Ohana (2021)
# Processing 995/9515: Three (2016)
# Processing 996/9515: Aziz Ansari: Right Now (2019)
# Processing 997/9515: Bill Hicks: Revelations (1993)
# Processing 998/9515: Love Happens (2009)
# Processing 999/9515: The Wind (2019)
# Processing 1000/9515: Habibie & Ainun (2012)
# Processed 1000 movies. Pausing for rate limiting...
# Processing 1001/9515: Feel the Beat (2020)
# Processing 1002/9515: Hotel for Dogs (2009)
# Processing 1003/9515: Silver Skates (2020)
# Processing 1004/9515: Elizabeth Harvest (2018)
# Processing 1005/9515: Joseph: King of Dreams (2000)
# Processing 1006/9515: Choked: Paisa Bolta Hai (2020)
# Processing 1007/9515: Carrie Pilby (2017)
# Processing 1008/9515: Blame! (2017)
# Processing 1009/9515: Ala Vaikunthapurramuloo (2020)
# Processing 1010/9515: The Operative (2019)
# Processing 1011/9515: Pelé (2021)
# Processing 1012/9515: Little Evil (2017)
# Processing 1013/9515: Mersal (2017)
# Processing 1014/9515: Hannah Gadsby: Douglas (2020)
# Processing 1015/9515: Operation Christmas Drop (2020)
# Processing 1016/9515: Pokémon the Movie: I Choose You! (2017)
# Processing 1017/9515: Sweetheart (2019)
# Processing 1018/9515: Delirium (2018)
# Processing 1019/9515: The Bar (2017)
# Processing 1020/9515: Herod's Law (1999)
# Processing 1021/9515: A Princess for Christmas (2011)
# Processing 1022/9515: Triple Threat (2019)
# Processing 1023/9515: Kevin Hart: What Now? (2016)
# Processing 1024/9515: Goon: Last of the Enforcers (2017)
# Processing 1025/9515: The Unknown Known (2013)
# Processing 1026/9515: The Paramedic (2020)
# ...
# Processing 9253/9515: Into the Okavango (2018)
# Processing 9254/9515: Donald Duck: The Wise Little Hen (1934)
# Processing 9255/9515: Toby Tortoise Returns (1936)
# Processing 9256/9515: Out of Scale (1951)
# Processing 9257/9515: Mr. Mouse Takes a Trip (1940)
# Processing 9258/9515: Up, Up, and Away (2000)
# Processing 9259/9515: Expedition Amelia (2019)
# Processing 9260/9515: Beach Picnic (1939)
# Processing 9261/9515: Almost Angels (1962)
# Processing 9262/9515: Babes in the Woods (1932)
# Processing 9263/9515: Forky Asks a Question: What Is Love? (2019)
# Processing 9264/9515: Early to Bed (1941)
# Processing 9265/9515: The Castaway Cowboy (1974)
# Processing 9266/9515: Hawaiian Holiday (1937)
# Processing 9267/9515: Lend a Paw (1941)
# Processing 9268/9515: Corn Chips (1951)
# Processing 9269/9515: The African Lion (1955)
# Processing 9270/9515: Jane Goodall: The Hope (2020)
# Processing 9271/9515: Zenon: Z3 (2004)
# Processing 9272/9515: Gender Revolution: A Journey with Katie Couric (2017)
# Processing 9273/9515: Life-Size 2: A Christmas Eve (2018)
# Processing 9274/9515: Winter Storage (1949)
# Processing 9275/9515: The Olympic Champ (1942)
# Processing 9276/9515: Growing Fangs (2021)
# Processing 9277/9515: High School Musical: The Musical: The Series: The Special (2019)
# Processing 9278/9515: Three Blind Mouseketeers (1936)
# Processing 9279/9515: Young Black Stallion (2003)
# Processing 9280/9515: Trailer Horn (1950)
# Processing 9281/9515: How to Swim (1942)
# Processing 9282/9515: Kazaam (1996)
# Processing 9283/9515: Double Dribble (1946)
# Processing 9284/9515: How to Play Football (1944)
# Processing 9285/9515: Orca Vs Great White (2021)
# Processing 9286/9515: Ye Olden Days (1933)
# Processing 9287/9515: The Little Whirlwind (1941)
# Processing 9288/9515: Bride of Boogedy (1987)
# Processing 9289/9515: The Last of the Chupacabras (2021)
# Processing 9290/9515: Forky Asks a Question: What Is Cheese? (2020)
# Processing 9291/9515: LEGO Star Wars: The New Yoda Chronicles - Escape from the Jedi Temple (2014)
# Processing 9292/9515: Forky Asks a Question: What Is Money? (2019)
# Processing 9293/9515: The Simple Things (1953)
# Processing 9294/9515: Dinner Is Served (2021)
# Processing 9295/9515: Captain Sparky vs. The Flying Saucers (2013)
# Processing 9296/9515: Lost on Everest (2020)
# Processing 9297/9515: Breaking2 (2017)
# Processing 9298/9515: The Pied Piper (1933)
# Processing 9299/9515: Meet the Deedles (1998)
# Processing 9300/9515: Mickey's Birthday Party (1942)
# Processed 9300 movies. Pausing for rate limiting...
# Processing 9301/9515: The Ultimate Christmas Present (2000)
# Processing 9302/9515: Dolphin Reef (2018)
# Processing 9303/9515: Dragon Around (1954)
# Processing 9304/9515: Lego Star Wars: The Yoda Chronicles - Raid on Coruscant (2014)
# Processing 9305/9515: Mickey's Rival (1936)
# Processing 9306/9515: Treasure Buddies (2012)
# Processing 9307/9515: Mars: One Day on the Red Planet (2020)
# Processing 9308/9515: Moon Mater (2010)
# Processing 9309/9515: Donald's Golf Game (1938)
# Processing 9310/9515: Those Calloways (1965)
# Processing 9311/9515: LEGO Star Wars: The New Yoda Chronicles - Race For The Holocrons (2014)
# Processing 9312/9515: Don's Fountain of Youth (1953)
# Processing 9313/9515: Donald's Dog Laundry (1940)
# Processing 9314/9515: Sea Scouts (1939)
# Processing 9315/9515: Jungle Cat (1959)
# Processing 9316/9515: Santa Paws 2: The Santa Pups (2012)
# Processing 9317/9515: Forky Asks a Question: What Is Time? (2019)
# Processing 9318/9515: Rogue Shark? (2021)
# Processing 9319/9515: Mickey Mouse: Mickey's Delayed Date (1947)
# Processing 9320/9515: Morning Light (2008)
# Processing 9321/9515: Marvel Rising: Chasing Ghosts (2019)
# Processing 9322/9515: The Golden Touch (1935)
# Processing 9323/9515: You Wish! (2003)
# Processing 9324/9515: Inspector Gadget 2 (2003)
# Processing 9325/9515: Forky Asks a Question: What Is Art? (2019)
# Processing 9326/9515: Donald's Tire Trouble (1943)
# Processing 9327/9515: Stepsister from Planet Weird (2000)
# Processing 9328/9515: The New Neighbor (1953)
# Processing 9329/9515: Under the Sea: A Descendants Story (2018)
# Processing 9330/9515: Super Rhino (2009)
# Processing 9331/9515: Forky Asks a Question: What Is a Computer? (2019)
# Processing 9332/9515: The Adventures of Bullwhip Griffin (1967)
# Processing 9333/9515: Man in Space (1955)
# Processing 9334/9515: Society Dog Show (1939)
# Processing 9335/9515: Marvel Rising: Heart of Iron (2019)
# Processing 9336/9515: Bearly Asleep (1955)
# Processing 9337/9515: Back To The Titanic (2020)
# Processing 9338/9515: Emil and the Detectives (1964)
# Processing 9339/9515: Forky Asks a Question: What is Reading? (2020)
# Processing 9340/9515: Okavango: River of Dreams (2019)
# Processing 9341/9515: Life Is Ruff (2005)
# Processing 9342/9515: Rescue Dog (1947)
# Processing 9343/9515: Walt & El Grupo (2008)
# Processing 9344/9515: Grand Canyonscope (1954)
# Processing 9345/9515: Treasure of Matecumbe (1976)
# Processing 9346/9515: Let's Stick Together (1952)
# Processing 9347/9515: The Biscuit Eater (1972)
# Processing 9348/9515: Pluto's Party (1952)
# Processing 9349/9515: Drain the Titanic (2016)
# Processing 9350/9515: Hannah Montana & Miley Cyrus: Best of Both Worlds Concert (2008)
# Processed 9350 movies. Pausing for rate limiting...
# Processing 9351/9515: Beezy Bear (1955)
# Processing 9352/9515: Miracle at Midnight (1998)
# Processing 9353/9515: Own the Room (2021)
# Processing 9354/9515: Recess: All Growed Down (2003)
# Processing 9355/9515: Food for Feudin' (1950)
# Processing 9356/9515: The Secret of the Magic Gourd (2007)
# Processing 9357/9515: Forky Asks a Question: What Is a Leader? (2019)
# Processing 9358/9515: Can of Worms (1999)
# Processing 9359/9515: The Lost Tomb of Alexander the Great (2019)
# Processing 9360/9515: Myth: A Frozen Tale (2020)
# Processing 9361/9515: Pluto's Purchase (1948)
# Processing 9362/9515: Pluto and the Gopher (1950)
# Processing 9363/9515: Decorating Disney: Holiday Magic (2017)
# Processing 9364/9515: The Vanishing Prairie (1954)
# Processing 9365/9515: Hounded (2001)
# Processing 9366/9515: Perri (1957)
# Processing 9367/9515: Sacred Planet (2004)
# Processing 9368/9515: The Bears and I (1974)
# Processing 9369/9515: World's Biggest Bull Shark? (2021)
# Processing 9370/9515: Canine Caddy (1941)
# Processing 9371/9515: Unidentified Flying Oddball (1979)
# Processing 9372/9515: Secrets of Life (1956)
# Processing 9373/9515: Marvel Rising: Battle of the Bands (2019)
# Processing 9374/9515: Forky Asks a Question: What Is a Pet? (2019)
# Processing 9375/9515: Shark Gangs (2021)
# Processing 9376/9515: The Adventures of André and Wally B. (1984)
# Processing 9377/9515: Buffalo Dreams (2005)
# Processing 9378/9515: Mark Twain and Me (1991)
# Processing 9379/9515: In the Footsteps of Elephant (2020)
# Processing 9380/9515: 'Twas the Night (2001)
# Processing 9381/9515: Yellowstone Cubs (1963)
# Processing 9382/9515: A Celebration of the Music from Coco (2020)
# Processing 9383/9515: The Christmas Star (1986)
# Processing 9384/9515: Mail Dog (1947)
# Processing 9385/9515: Full-Court Miracle (2003)
# Processing 9386/9515: Cesar Millan: The Real Story (2012)
# Processing 9387/9515: Mickey Down Under (1948)
# Processing 9388/9515: High School Musical: The Musical: The Holiday Special (2020)
# Processing 9389/9515: Marvel Rising: Playing with Fire (2019)
# Processing 9390/9515: Playdate with Destiny (2020)
# Processing 9391/9515: Dory's Reef Cam (2020)
# Processing 9392/9515: Pompeii: Secrets of the Dead (2019)
# Processing 9393/9515: The Ghosts of Buxley Hall (1980)
# Processing 9394/9515: Pluto's Sweater (1949)
# Processing 9395/9515: Fuzzbucket (1986)
# Processing 9396/9515: Mission to the Sun (2018)
# Processing 9397/9515: Jingle Pols (2013)
# Processing 9398/9515: Drain Alcatraz (2017)
# Processing 9399/9515: Drain the Bermuda Triangle (2014)
# Processing 9400/9515: Marvel Rising: Operation Shuri (2019)
# Processed 9400 movies. Pausing for rate limiting...
# Processing 9401/9515: Lost Temple of The Inca (2020)
# Processing 9402/9515: Skyrunners (2009)
# Processing 9403/9515: The Plausible Impossible (1956)
# Processing 9404/9515: Bizarre Dinosaurs (2009)
# Processing 9405/9515: Star Wars: Galaxy's Edge - Adventure Awaits (2019)
# Processing 9406/9515: Trail of the Panda (2009)
# Processing 9407/9515: Incredible! The Story of Dr. Pol (2015)
# Processing 9408/9515: Notre Dame: Race Against the Inferno (2019)
# Processing 9409/9515: The Disney Holiday Singalong (2020)
# Processing 9410/9515: Prowlers of the Everglades (1953)
# Processing 9411/9515: Bone Bandit (1948)
# Processing 9412/9515: Miracle Landing on the Hudson (2014)
# Processing 9413/9515: Drain The Ocean: WWII (2016)
# Processing 9414/9515: Jonas Brothers: The Concert Experience (2009)
# Processing 9415/9515: The Sign of Zorro (1958)
# Processing 9416/9515: Casebusters (1986)
# Processing 9417/9515: The New Yoda Chronicles: Clash of the Skywalkers (2014)
# Processing 9418/9515: Expedition Everest (2020)
# Processing 9419/9515: The Pre-Opening Report from Disneyland (1955)
# Processing 9420/9515: Ready to Run (2000)
# Processing 9421/9515: From Our Family to Yours (2020)
# Processing 9422/9515: The Poof Point (2001)
# Processing 9423/9515: 700 Sharks (2018)
# Processing 9424/9515: How Dogs Got Their Shapes (2016)
# Processing 9425/9515: Pluto's Surprise Package (1949)
# Processing 9426/9515: Diving with Dolphins (2020)
# Processing 9427/9515: Petra: Secrets of the Ancient Builders (2020)
# Processing 9428/9515: Surviving the Mount St. Helens Disaster (2020)
# Processing 9429/9515: A Tale of Two Critters (1977)
# Processing 9430/9515: The Olympic Elk (1952)
# Processing 9431/9515: You Lucky Dog (1998)
# Processing 9432/9515: Easter Island Unsolved (2018)
# Processing 9433/9515: Kingdom of the Blue Whale (2009)
# Processing 9434/9515: The Story of the Faithful Wookiee (1978)
# Processing 9435/9515: Secrets of the Bull Shark (2020)
# Processing 9436/9515: Drain the Great Lakes (2011)
# Processing 9437/9515: Drain The Sunken Pirate City (2017)
# Processing 9438/9515: Whispers: An Elephant's Tale (2000)
# Processing 9439/9515: Sharks of Lost Island (2013)
# Processing 9440/9515: Nature's Half Acre (1951)
# Processing 9441/9515: The Jungle Book: Mowgli's Story (1998)
# Processing 9442/9515: The Last Ice (2020)
# Processing 9443/9515: Blue Ribbon Kids (2016)
# Processing 9444/9515: Stonehenge: Decoded (2008)
# Processing 9445/9515: Paris to Pittsburgh (2018)
# Processing 9446/9515: The Story of the Animated Drawing (1955)
# Processing 9447/9515: Water Birds (1952)
# Processing 9448/9515: Hamilton: History Has Its Eyes On You (2020)
# Processing 9449/9515: The Hidden Kingdoms of China (2020)
# Processing 9450/9515: LEGO Star Wars: The New Yoda Chronicles – Duel of the Skywalkers (2014)
# Processed 9450 movies. Pausing for rate limiting...
# Processing 9451/9515: Mega Hammerhead (2016)
# Processing 9452/9515: The Mouseketeers at Walt Disney World (1977)
# Processing 9453/9515: Buried Truth of the Maya (2020)
# Processing 9454/9515: Sammy, the Way-Out Seal (1962)
# Processing 9455/9515: Shark vs. Surfer (2020)
# Processing 9456/9515: Oil Spill of The Century (2018)
# Processing 9457/9515: My Dog the Thief (1969)
# Processing 9458/9515: The Liberty Story (1957)
# Processing 9459/9515: Hacksaw (1971)
# Processing 9460/9515: Big Sur-Wild California (2010)
# Processing 9461/9515: Secrets of Christ's Tomb: Explorer Special (2017)
# Processing 9462/9515: Cradle of the Gods (2012)
# Processing 9463/9515: Justin Morgan Had a Horse (1972)
# Processing 9464/9515: Disney Illuminations Firework Show Disneyland Paris (2017)
# Processing 9465/9515: Richie Rich's Christmas Wish (1998)
# Processing 9466/9515: Secrets of the King Cobra (2010)
# Processing 9467/9515: Viking Warrior Women (2019)
# Processing 9468/9515: Egypt's Treasure Guardians (2016)
# Processing 9469/9515: Born Wild: The Next Generation (2020)
# Processing 9470/9515: Chasing the Equinox (2019)
# Processing 9471/9515: Kingdom of the Apes: Battle Lines (2014)
# Processing 9472/9515: Arendelle Castle Yule Log (2019)
# Processing 9473/9515: Giants of the Deep Blue (2017)
# Processing 9474/9515: America's Greatest Animals (2012)
# Processing 9475/9515: Sea of Hope: America's Underwater Treasures (2017)
# Processing 9476/9515: Being the Queen (2020)
# Processing 9477/9515: Winged Seduction: Birds of Paradise (2012)
# Processing 9478/9515: The Boy Who Talked to Badgers (1975)
# Processing 9479/9515: Man vs. Shark (2019)
# Processing 9480/9515: The Lost City of Machu Picchu (2019)
# Processing 9481/9515: Tree Climbing Lions (2018)
# Processing 9482/9515: Planet of the Birds (2018)
# Processing 9483/9515: The Undefeated Presents: Hamilton In-Depth (2020)
# Processing 9484/9515: Penguins: Life on the Edge (2020)
# Processing 9485/9515: Wild Portugal (2020)
# Processing 9486/9515: Disney My Music Story: Perfume (2020)
# Processing 9487/9515: Shanghai Disney Resort Grand Opening Special (2016)
# Processing 9488/9515: Shark vs. Whale (2020)
# Processing 9489/9515: Shark Attack Investigation: The Paige Winter Story (2020)
# Processing 9490/9515: Disney Holiday Magic Quest (2020)
# Processing 9491/9515: India's Wild Leopards (2020)
# Processing 9492/9515: Journey to Shark Eden (2009)
# Processing 9493/9515: Man Among Cheetahs (2017)
# Processing 9494/9515: Big Sharks Rule (2018)
# Processing 9495/9515: Sultan And The Rock Star (1980)
# Processing 9496/9515: My Music Story: Yoshiki (2021)
# Processing 9497/9515: Disney Channel Halloween House Party (2020)
# Processing 9498/9515: Earth Live (2017)
# Processing 9499/9515: World's Greatest Dogs (2015)
# Processing 9500/9515: Wild Uganda (2018)
# Processed 9500 movies. Pausing for rate limiting...
# Processing 9501/9515: Challenge Accepted! Disney Channel's Epic Holiday Showdown (2020)
# Processing 9502/9515: Sharks of the Bermuda Triangle (2020)
# Processing 9503/9515: Sharkcano (2020)
# Processing 9504/9515: Disney My Music Story: Sukima Switch (2021)
# Processing 9505/9515: Big Cat Games (2015)
# Processing 9506/9515: Great Shark Chow Down (2019)
# Processing 9507/9515: In Beaver Valley (1950)
# Processing 9508/9515: Texas Storm Squad (2020)
# Processing 9509/9515: What the Shark? (2020)
# Processing 9510/9515: Built for Mars: The Perseverance Rover (2021)
# Processing 9511/9515: Most Wanted Sharks (2020)
# Processing 9512/9515: Doc McStuffins: The Doc Is In (2020)
# Processing 9513/9515: Ultimate Viking Sword (2019)
# Processing 9514/9515: Hunt for the Abominable Snowman (2011)
# Processing 9515/9515: Women of Impact: Changing the World (2019)
#
# === Final Results ===
# Movies processed: 9515
# Successfully matched: 9332
# Not found: 183
# Details failed: 0
#
# Budget statistics (non-zero values):
#   Movies with budget data: 2412
#   Average budget: $26,291,414
#   Median budget: $10,000,000
#   Max budget: $489,900,000
#
# Revenue statistics (non-zero values):
#   Movies with revenue data: 2483
#   Average revenue: $75,790,356
#   Median revenue: $12,127,842
#   Max revenue: $2,923,706,026
#
# Runtime statistics:
#   Movies with runtime data: 9332
#   Average runtime: 93.5 minutes
#   Median runtime: 94.0 minutes
#   Max runtime: 317.0 minutes
#
# Complete enriched dataset saved to 'movies_with_tmdb_data_complete.csv'
#
# Sample of enriched data:
#                                    Title  Year      budget     revenue  runtime  status
#                             The Irishman  2019 159000000.0    968853.0    209.0 success
#                                   Dangal  2016  10400000.0 311000000.0    161.0 success
# David Attenborough: A Life on Our Planet  2020         0.0         0.0     83.0 success
#        Lagaan: Once Upon a Time in India  2001   5200000.0   8100000.0    233.0 success
#                                     Roma  2018  15000000.0   1140769.0    135.0 success
#        To All the Boys I've Loved Before  2018         0.0         0.0    100.0 success
#                       The Social Dilemma  2020         0.0         0.0     94.0 success
#                                     Okja  2017  50000000.0         0.0    120.0 success
#             The Ballad of Buster Scruggs  2018         0.0         0.0    132.0 success
#               The Trial of the Chicago 7  2020  35000000.0    107423.0    130.0 success
#
# ============================================================
# PROCESSING COMPLETE!
# ============================================================

# %%
df = pd.read_csv("movies_with_tmdb_data_complete.csv")

# Dropping unuseful columns
df = df.drop(columns=["title"])
df = df.drop(columns=["keywords"])
df = df.drop(columns=["status"])
df = df.drop(columns=["tmdb_id"])

# filtering the data to only movies with a reported budget and revenue
df = df[df["budget"] >0]
df = df[df["revenue"] >0]

# Creating release age feature
df['Release_age'] = 2025 - df['Year']

df.head(5)

# %%
# Keeping only rows with a tagline 
df_filtered = df[df['tagline'].notnull()]
df_filtered.head()

# %%
df_filtered.to_csv('movies_with_tmdb_data_complete.csv', index=False)
